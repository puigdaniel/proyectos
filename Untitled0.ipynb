# %% [markdown]
# <a href="https://colab.research.google.com/github/puigdaniel/proyectos/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lista = [3, 1, 2, 4, 6, 9, 8]
lista.append(5)
lista.append(7)
lista.sort()
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
